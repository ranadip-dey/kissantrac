# %%
from bs4 import BeautifulSoup
import urllib.request as urllib2
from urllib.request import urlretrieve
import urllib.request
import shutil
import requests
#from urlparse import urljoin
import sys
import time

def make_soup(url):
    req = urllib2.Request(url, headers={'User-Agent' : "Magic Browser"}) 
    html = urllib2.urlopen(req)
    return BeautifulSoup(html, 'html.parser')

def get_images(url):
    soup = make_soup(url)
    page_body = soup.body
    first_h1 = soup.select('h1')[0].text
    images = [img for img in page_body.findAll('img', attrs={'class':'responsive-img materialboxed imageBox1 valign'})]
    print (str(len(images)) + " images found.")
    print ('Downloading images to current working directory.')
    image_links = [each.get('data-src') for each in images]
    for each in image_links:
        try:
            filename = each.strip().split('/')[-1].strip()
            print ('Getting: ' + each)
            r = requests.get(each, stream=True, headers={'User-agent': 'Mozilla/5.0'})
            if r.status_code == 200:
                with open(first_h1 + ".jpg", 'wb') as f:
                    r.raw.decode_content = True
                    shutil.copyfileobj(r.raw, f)
            
        except  Exception as e: # work on python 3.x
            print ('  An error occured. Continuing.'+ str(e))
    print('Done.')



file1 = open('links57.csv', 'r')
Lines = file1.readlines()
 
# Strips the newline character
for line in Lines:
    line= line.rstrip()
    get_images(line)
print("all file downloaded.")
# Out:
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-42-di-sikander.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/wt-60-rx-1598356672.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-gt-28-tiger.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-745-iii-701633.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/tiger-50-1600064450.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-750iii-887082.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-60-sikander-1597910133.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/tiger-electric-1609128888.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-20-1598356211.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/gt-22-rx-1597901339.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/gt-26-rx-1597901371.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-30-rx-bagban-super-353475.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-30-baagban-super-1597901408.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-730-ii-hdm-1597904784.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-30-baagban-537172.png
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-32-rx-1578890246.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-734-s1-949890.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-mm-35-di.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-35-rx-442455.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-35-di-sikandar.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-mm-39-di.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-35.JPG
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-35-rx-sikandar.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/rx-42-mahabali-1609911487.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-mm-41-di.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-42rx-414906.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-740-iii-s3-312105.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-42-rx-sikandar.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-745-dlx-1602147680.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-47-rx-623178.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-745-rx-iii-sikander.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/47-rx-sikander-1597906033.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/tiger-47-1600064511.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/rx-47-mahabali-1609911475.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-745-di-iii-sikander.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-mm-45-di.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-mm-50.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-50-rx-1579073835.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/50-rx-sikander-1597906269.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-50-dlx-1602141353.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-60-mm-super-rx-931187.png
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-50-sikander-1597912837.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-60-mm-super-910960.png
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/rx-750-iii-dlx-1601446796.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-750-iii-rx-sikandar-931790.png
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-750-iii-multi-speed-dlx-1602141296.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/tiger-55-1600064477.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/rx-55-dlx-1602071902.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-750-sikander.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-750-iii-dlx-1602148210.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-55-dlx-1602141009.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/wt-60-rx-sikander-1597910249.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-60-1599027839.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/worldtrac-60-rx-1578674374.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/60-rx-sikander-1597910190.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-60-rx-4wd-462891.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/di-60-dlx-1602141094.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/tiger-60-1600064539.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-di-60-rx-720774.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/rx-60-dlx-1602071844.jpg
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/sonalika-worldtrac-75-rx-2wd-4wd-787318.jpg
#   An error occured. Continuing.[Errno 2] No such file or directory: 'Sonalika Worldtrac 75 RX 2WD / 4WD.jpg'
# Done.
# 1 images found.
# Downloading images to current working directory.
# Getting: https://cdn.tractorguru.com/upload/worldtrac-90-rx-4wd-1598356788.jpg
# Done.
# all file downloaded.
